# %%
import pandas as pd
from sqlalchemy import create_engine
import numpy as np

# from sklearnex import patch_sklearn

# patch_sklearn()
engine = create_engine("mysql+pymysql://joe:][poiu123@111.230.36.157:54321/tcrdb")

sql_query = """
SELECT resistance as Rc,
contact_material_1_id as mat1,
contact_material_2_id as mat2,
mat1.material_name as name1,
mat2.material_name as name2,
mat_1_ra as ra1,
mat_2_ra as ra2,
mat_1_rsm as rsm1,
mat_2_rsm as rsm2,
ambient_pressure as Pa,
interface_temperature as T,
contact_pressure as Pc,
r.description,
r.ref_id
FROM resistance r
LEFT JOIN material mat1 ON r.contact_material_1_id = mat1.mat_id
LEFT JOIN material mat2 ON r.contact_material_2_id = mat2.mat_id
"""

df_read = pd.read_sql_query(sql_query, engine)
df_r2 = df_read[~df_read["description"].str.contains("LPM|LMP|He|N2|loading|CSP")]
df_r2 = df_r2[(df_r2["Pa"] == 101325) | (df_r2["Pa"] == 0)]
# df_r2 = df_r2[(df_r2["name1"] != "cc") & (df_r2["name2"] != "cc")]
import sys

sys.path.insert(0, "/home/joe/Documents/pytorch/")

# %%
df_r3 = df_r2[~(df_r2["ref_id"] == 23)]
idx1 = (df_r3["ra1"] == 0) & (df_r3["rsm1"] != 0)
df_r3.loc[idx1, "ra1"] = df_r3.loc[idx1, "rsm1"] / 1.25
df_r3.loc[idx1, "ra2"] = df_r3.loc[idx1, "rsm2"] / 1.25
idx2 = (df_r3["ra2"] != 0) & (df_r3["rsm2"] == 0)
df_r3.loc[idx2, "rsm2"] = df_r3.loc[idx2, "ra2"] * 1.25
df_r3.loc[idx2, "rsm1"] = df_r3.loc[idx2, "ra1"] * 1.25
idx3 = df_r3["Pc"] == 0
df_r3.loc[idx3, "Pc"] = 1e3


from sklearn.model_selection import train_test_split

df_r3.head()
features = [
    "rsm1",
    "rsm2",
    "T",
    "Pc",
    "Pa",
    "mat1",
    "mat2",
]

df_r4 = df_r3.copy()

prop_cols = [
    "k1",
    "A1",
    "E1",
    "v1",
    "Cp1",
    "rho1",
    "H1",
    "k2",
    "A2",
    "E2",
    "v2",
    "Cp2",
    "rho2",
    "H2",
]
df_r4[prop_cols] = 0.0
from util.mat.mat_db import MatDb

db = MatDb(max_embedding_dim=100)


def process_row(row):
    return pd.Series(
        db.get_prop(row["mat1"], row["T"] + 273.15)
        + db.get_prop(row["mat2"], row["T"] + 273.15)
    )


df_r4[prop_cols] = df_r4.apply(process_row, axis=1)
# Out:
# x and y arrays must be equal in length along interpolation axis.
# x and y arrays must be equal in length along interpolation axis.
# x and y arrays must be equal in length along interpolation axis.
# x and y arrays must be equal in length along interpolation axis.
# x and y arrays must be equal in length along interpolation axis.
# x and y arrays must be equal in length along interpolation axis.
# x and y arrays must be equal in length along interpolation axis.
# x and y arrays must be equal in length along interpolation axis.
# x and y arrays must be equal in length along interpolation axis.
# x and y arrays must be equal in length along interpolation axis.
# x and y arrays must be equal in length along interpolation axis.
# x and y arrays must be equal in length along interpolation axis.
# x and y arrays must be equal in length along interpolation axis.
# x and y arrays must be equal in length along interpolation axis.
# x and y arrays must be equal in length along interpolation axis.
# x and y arrays must be equal in length along interpolation axis.
# x and y arrays must be equal in length along interpolation axis.
# x and y arrays must be equal in length along interpolation axis.
# x and y arrays must be equal in length along interpolation axis.
# x and y arrays must be equal in length along interpolation axis.
# x and y arrays must be equal in length along interpolation axis.
# x and y arrays must be equal in length along interpolation axis.
# x and y arrays must be equal in length along interpolation axis.
# x and y arrays must be equal in length along interpolation axis.
# x and y arrays must be equal in length along interpolation axis.
# x and y arrays must be equal in length along interpolation axis.
# x and y arrays must be equal in length along interpolation axis.
# x and y arrays must be equal in length along interpolation axis.
# x and y arrays must be equal in length along interpolation axis.
# x and y arrays must be equal in length along interpolation axis.
# x and y arrays must be equal in length along interpolation axis.
# x and y arrays must be equal in length along interpolation axis.
# x and y arrays must be equal in length along interpolation axis.
# x and y arrays must be equal in length along interpolation axis.
